# %%
#importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.Creating a DATAFRAME from an array

# %%
# creating the array
arr=np.array([[1,2],[2,3],[4,5]])
arr
# Out:
# array([[1, 2],
#        [2, 3],
#        [4, 5]])

# %%
#creating a datafarme
pd.DataFrame(arr)
# Out:
#    0  1
# 0  1  2
# 1  2  3
# 2  4  5

# %%
# creating DataFrame with customized row(index) and columns name
pd.DataFrame(arr,index=['row1','row2','row3'],columns=['col1','col2'])
# Out:
#       col1  col2
# row1     1     2
# row2     2     3
# row3     4     5
