# %%
#importing libraries
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.Creating a DATAFRAME from an array

# %%
# creating the array
arr=np.array([[1,2],[2,3],[4,5]])
arr
# Out:
# array([[1, 2],
#        [2, 3],
#        [4, 5]])

# %%
#creating a datafarme
pd.DataFrame(arr)
# Out:
#    0  1
# 0  1  2
# 1  2  3
# 2  4  5

# %%
# creating DataFrame with customized row(index) and columns name
df=pd.DataFrame(arr,index=['row1','row2','row3'],columns=['col1','col2'])
df
# Out:
#       col1  col2
# row1     1     2
# row2     2     3
# row3     4     5

# %% [markdown]
# # Creating DataFrame using Dictionary

# %%
# List used for this example
states=['California','Texas','Florida','New York']
population=[12345678,98765392,89146738,56382913]

# %%
#creating dictionary
dict_states={'States':states,'Population':population}

# %%
# creating DataFrame using Dictionary
df_population=pd.DataFrame(dict_states)
df
# Out:
#        States  Population
# 0  California    12345678
# 1       Texas    98765392
# 2     Florida    89146738
# 3    New York    56382913

# %% [markdown]
# # Creating Dataframe From CSV files

# %%
# reading the csv file
df_csv=pd.read_csv("StudentsPerformance.csv")

# %%
# showing first 5 rows
df_csv.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
