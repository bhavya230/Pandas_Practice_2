# %%
import pandas as pd

# %%
# reads csv file
df = pd.read_csv('players_20.csv')

# set index
df.set_index('short_name', inplace=True)
# select column

df = df[['long_name', 'age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']]

# %%
df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %% [markdown]
# # copy()
#
# the .copy() function is used to create a copy of a DataFrame or Series.
#
# **📌 Why .copy() is important**
#
# Without .copy(), sometimes variables may share the same data, so changing one can unintentionally change the other.
#
# **📌 Syntax**
#
# df_copy = df.copy(deep=True)
#
# **📌 Without .copy() (problem case)**
#
# df2 = df   # no copy, just reference
#
# df2['A'][0] = 100
#
# print(df)   # also changes!
#
# 👉 Both change because they point to the same object

# %% [markdown]
# ## 1 DEEP COPY
# df_copy = df.copy(deep=True)
#
# Completely independent copy
#
# Changes do NOT affect original

# %%
df_copy=df.copy()
df_copy.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        187         83    Portugal             Juventus
# Neymar Jr                175         68      Brazil  Paris Saint-Germain
# J. Oblak                 188         87    Slovenia      Atlético Madrid
# E. Hazard                175         74     Belgium          Real Madrid

# %%
# update value in original dataframe

df['height_cm']=170
df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        170         83    Portugal             Juventus
# Neymar Jr                170         68      Brazil  Paris Saint-Germain
# J. Oblak                 170         87    Slovenia      Atlético Madrid
# E. Hazard                170         74     Belgium          Real Madrid

# %%
# copy vs original dataframe
df_copy.head()

df.head()
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
#
#                    height_cm  weight_kg nationality                 club
# short_name
# L. Messi                 170         72   Argentina         FC Barcelona
# Cristiano Ronaldo        170         83    Portugal             Juventus
# Neymar Jr                170         68      Brazil  Paris Saint-Germain
# J. Oblak                 170         87    Slovenia      Atlético Madrid
# E. Hazard                170         74     Belgium          Real Madrid

# %% [markdown]
# ## 2 SHALLOW COPY
# df_copy = df.copy(deep=False)
#
# Shares underlying data
#
# Changes may affect both

# %%
df_shallow_copy=df.copy(deep=False)
df_shallow_copy
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %%
df['weight_kg']=90

# %%
# shallow copy vs deep copy
df_shallow_copy.head(1) # no change --- 👉 Why?
#Because you replaced the whole column → new memory allocated
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   32  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona

# %%
df.loc['L. Messi','age']=45

# %%
# compare the shallow 
df_shallow_copy.head(1)
# Out:
#                                  long_name  age         dob  height_cm  \
# short_name
# L. Messi    Lionel Andrés Messi Cuccittini   45  1987-06-24        170
#
#             weight_kg nationality          club
# short_name
# L. Messi           72   Argentina  FC Barcelona
